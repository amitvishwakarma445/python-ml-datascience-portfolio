# %% [markdown]
# # Data Visualization with seaborn
#
# * seaborn is a data visualization library library based on **Mataplotlib** that provides<br>a high-level-interface for drawing attractive and information statical graphics.
# * seaborn helps in creating complex data visualizions with just a few lines of code.

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
## Basic ploting with seaborn

tips_dataSource = sns.load_dataset('tips')   ## tips- built in record in seaborn to study
display(tips_dataSource)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## 1. Create a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill', y='tip', data=tips_dataSource, color='red')

plt.title("Scatter plot of Bills vs Tip")
plt.show()

# %%
## line plot

sns.lineplot(x='size', y='total_bill', data = tips_dataSource)
plt.title("line plot of size VS total_bill")
plt.show()

# %%
## catagorical plots
## barplot

sns.barplot(x="day", y='total_bill', data=tips_dataSource)
plt.title("bar plot of total bill and day")
plt.show()

# %%
## box plot

sns.boxplot(x="day", y='total_bill', data=tips_dataSource)
plt.title("box plot of total bill and day")
plt.show()

# %%
## violin plot

sns.violinplot(x="day", y='total_bill', data=tips_dataSource)
plt.title("violin plot of total bill and day")
plt.show()

# %%
## Histogram Plot

sns.histplot(tips_dataSource['total_bill'], bins=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## Histogram Plot

sns.histplot(tips_dataSource['total_bill'], bins=10, kde=True) ### kde = Kernel Density Estimation line/curved_line to the histogram.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE plot : Kernel Density Estimation line/curved_line to the histogram.

sns.kdeplot(tips_dataSource["total_bill"], fill=True, color='red', edgecolor='black')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
tips_dataSource
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## pairplot (all combination of "tips_dataSource")

sns.pairplot(tips_dataSource)

# %% [markdown]
# ## corr() method
#
# * is a table with a lot of numbers that represents how well the relationship is between two columns.
# <br>
#
# * The number varies from -1 to 1.
# <br>
#
# * 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# * 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# * -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# * 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# **What is a good correlation?** It depends on the use, but I think it is safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.

# %%
## Heatmap :- like a aggrigation function [agg()]

correlations = tips_dataSource[['total_bill', 'tip', 'size']].corr()
display(correlations)


sns.heatmap(correlations, annot=True, cmap="coolwarm")
# annot = annotaion
# cmap = colormap= ('Blues', 'coolwarm', 'viridis', etc.)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
# <Axes: >

# %%
import pandas as pd

sales_DataFrame = pd.read_csv("sample_data.csv")
display(sales_DataFrame)
# Out:
#           Date     Category   Value     Product  Sales   Region
# 0   12/03/2024       Sports  326.29  Basketball   35.0  Central
# 1   03/03/2024    Furniture  102.75        Sofa   28.0     East
# 2   03/03/2024     Clothing  599.40        Sofa   41.0    South
# 3   26/03/2024       Sports  742.92     T-Shirt    8.0     West
# 4   03/02/2024    Groceries  373.55      Laptop    NaN     West
# 5   18/01/2024    Groceries  796.00  Basketball   50.0     East
# 6   30/03/2024     Clothing  985.11        Sofa   50.0  Central
# 7   30/01/2024  Electronics  481.91     T-Shirt   50.0    North
# 8   20/02/2024    Furniture  327.03     T-Shirt   50.0    South
# 9   26/01/2024    Groceries  390.75     T-Shirt   50.0  Central
# 10  16/02/2024    Groceries  269.44        Milk   50.0     East
# 11  23/02/2024  Electronics  849.36        Sofa   50.0     East
# 12  10/01/2024    Furniture     NaN        Milk    NaN     East
# 13  01/01/2024    Furniture  817.08  Basketball   50.0    North
# ...

# %%
## plot total sales by product
plt.figure(figsize=(6,3))

sns.barplot(x="Product", y="Sales", data=sales_DataFrame, estimator=sum)

plt.xlabel("Product")
plt.ylabel('Total Sales')
plt.title("Total sales by product")

plt.show()
